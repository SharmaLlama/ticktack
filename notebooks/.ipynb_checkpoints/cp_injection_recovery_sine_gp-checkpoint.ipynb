# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

import re
import jax.numpy as jnp
from jax import grad, jit, partial
import ticktack
from ticktack import fitting
from tqdm import tqdm
import scipy

rcParams['figure.figsize'] = (8.0, 4.0)

# %%
@jit
def sine(t):
    prod =  1.87 + 0.18 * 1.87 * jnp.sin(2 * jnp.pi / 11 * t + jnp.pi/2)
    return prod

# %%
cbm = ticktack.load_presaved_model('Guttler14', production_rate_units = 'atoms/cm^2/s')
cf = fitting.CarbonFitter(cbm)
cf.load_data('inject_recovery_sine.csv')
cf.prepare_function(use_control_points=True, interp='gp')

# %%
# %%time
soln = cf.fit_cp(low_bound=0.)
# Out:
# CPU times: user 11min 16s, sys: 1.92 s, total: 11min 18s
# Wall time: 10min 30s

# %%
soln.message
# Out:
# 'STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT'

# %%
print("total likelihood: ", cf.gp_likelihood(soln.x))
print("gp likelihood: ", cf.gp_neg_log_likelihood(soln.x))
print("chi2: ", cf.loss_chi2(soln.x))
# Out:
# total likelihood:  79.30848780824705
# gp likelihood:  79.2404516583923
# chi2:  0.0680361498547421

# %%
t = cf.control_points_time
true_cp = sine(t)
plt.plot(t, sine(t), ".")
plt.title('sine production rate')
# Out:
# Text(0.5, 1.0, 'sine production rate')

# %%
plt.plot(t, soln.x[:-1], ".", label="recovered")
plt.plot(t, true_cp, label='true')
plt.title("control points");
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True)

# %%
plt.plot(cf.time_data[:-1], cf.dc14(soln.x), ".k", label="recovered", markersize=10)
plt.plot(cf.time_data, cf.d14c_data, '--r')
plt.plot(cf.time_data, cf.d14c_data, 'or', fillstyle="none", label="true", alpha=0.5)
plt.title("d14c");
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True)

# %%
plt.plot(cf.time_data, cf.time_data, ".")

# %%
cf.time_data
# Out:
# DeviceArray([-426, -422, -418, -414, -413, -412, -411, -410, -409, -408,
#              -407, -406, -405, -404, -403, -402, -401, -400, -399, -398,
#              -397, -396, -395, -394, -390, -386, -382, -375, -373, -371,
#              -367, -365, -363, -361, -359, -357, -355, -353, -351, -349,
#              -347, -345, -343, -341, -339, -337, -335, -333, -331, -329,
#              -327], dtype=int64)

# %%
t = np.arange(cf.start-1000, cf.end+1)

# %%
prod = sine(t)
plt.plot(t, prod, "ob", fillstyle='none', markersize=1)
plt.plot(t, prod)
plt.plot(cf.control_points_time, sine(cf.control_points_time), "ob", fillstyle='none', markersize=1)
plt.plot(cf.control_points_time, sine(cf.control_points_time))
plt.xlim(-500, -320)
# Out:
# (-500.0, -320.0)

# %%
prod = cf.production(t, soln.x)
plt.plot(t, prod, "ob", fillstyle='none', markersize=1)
plt.plot(t, prod)
plt.xlim(-500, -320)
# Out:
# (-500.0, -320.0)

# %%
prod
# Out:
# DeviceArray([1.88410201, 1.88410201, 1.88410201, ..., 2.11421172,
#              1.94221986, 1.87415851], dtype=float64)

# %%
soln.x
# Out:
# array([1.73481592, 1.57313381, 1.51460236, 1.54205597, 1.69296061,
#        1.92638044, 2.02390008, 2.02901486, 2.00823464, 1.96971271,
#        1.94535871, 1.90460333, 1.75737994, 1.53488088, 1.49278517,
#        1.6187574 , 1.80735385, 1.99521077, 2.1339268 , 2.18531979,
#        2.13359721, 1.99344069, 1.80863156, 1.6380658 , 1.53642917,
#        1.53598935, 1.63580367, 1.80392992, 1.98935698, 2.13788857,
#        2.20402716, 2.14735618, 1.94022293, 1.69127506, 1.60565663,
#        1.61456084, 1.68773984, 1.80642376, 1.85882893, 1.88320408,
#        1.95647752, 2.06277574, 2.10620188, 2.08541465, 1.9720432 ,
#        1.79474694, 1.71987311, 1.71031913, 1.70771597, 1.7151711 ,
#        1.76149483, 1.93698132, 2.18883256, 2.19172478, 2.00511724,
#        1.81703802, 1.6195444 , 1.53343735, 1.54617536, 1.64473931,
#        1.81939341, 1.98520243, 2.13971682, 2.18423755, 2.13067923,
#        1.99959428, 1.80333424, 1.65078193, 1.54131796, 1.54586649,
#        1.6504936 , 1.80679469, 2.00354288, 2.1292661 , 2.1889818 ,
#        2.13753896, 1.99097801, 1.82271049, 1.64132326, 1.55295448,
#        1.54857706, 1.64330932, 1.82059429, 1.98683634, 2.13881441,
#        2.18482024, 2.13284557, 2.00154459, 1.80802085, 1.65596087,
#        1.54559262, 1.54976504, 1.65201871, 1.80601477, 2.00401875,
#        2.13558226, 2.19640488, 2.11421172, 1.94221986, 1.87415851,
#        1.88410201])

# %%
soln.x.size
# Out:
# 101

# %%
cf.control_points_time
# Out:
# DeviceArray([-426, -425, -424, -423, -422, -421, -420, -419, -418, -417,
#              -416, -415, -414, -413, -412, -411, -410, -409, -408, -407,
#              -406, -405, -404, -403, -402, -401, -400, -399, -398, -397,
#              -396, -395, -394, -393, -392, -391, -390, -389, -388, -387,
#              -386, -385, -384, -383, -382, -381, -380, -379, -378, -377,
#              -376, -375, -374, -373, -372, -371, -370, -369, -368, -367,
#              -366, -365, -364, -363, -362, -361, -360, -359, -358, -357,
#              -356, -355, -354, -353, -352, -351, -350, -349, -348, -347,
#              -346, -345, -344, -343, -342, -341, -340, -339, -338, -337,
#              -336, -335, -334, -333, -332, -331, -330, -329, -328, -327],            dtype=int64)
