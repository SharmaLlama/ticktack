# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

import re
import jax.numpy as jnp
from jax import grad, jit, partial
import ticktack
from ticktack import fitting

import blackjax.hmc as hmc
import blackjax.nuts as nuts
import blackjax.stan_warmup as stan_warmup
rcParams['figure.figsize'] = (16.0, 8.0)

# %%
cbm = ticktack.load_presaved_model('Guttler14', production_rate_units = 'atoms/cm^2/s')

# %%
cf = fitting.CarbonFitter(cbm)
cf.load_data('miyake12.csv')
cf.prepare_function(use_control_points=True)

# %%
steady_state = cf.steady_state_production * jnp.ones(((cf.end-cf.start+1)*1+1,))
offset = jnp.array([0.])
params = jnp.append(steady_state, offset)
bounds = tuple([(cf.steady_state_production, None)] * len(steady_state) + [(0, None)])

# %%
params
# Out:
# DeviceArray([1.87308861, 1.87308861, 1.87308861, 1.87308861, 1.87308861,
#              1.87308861, 1.87308861, 1.87308861, 1.87308861, 1.87308861,
#              1.87308861, 1.87308861, 1.87308861, 1.87308861, 1.87308861,
#              1.87308861, 1.87308861, 1.87308861, 1.87308861, 1.87308861,
#              1.87308861, 1.87308861, 1.87308861, 1.87308861, 1.87308861,
#              1.87308861, 1.87308861, 1.87308861, 1.87308861, 0.        ],            dtype=float64)

# %%
mcmc = MCMC(HMC(cf.log_like), num_warmup=100, num_samples=200)
mcmc.run(random.PRNGKey(0), init_params=params)
first_100_samples = mcmc.get_samples()
mcmc.post_warmup_state = mcmc.last_state
mcmc.run(mcmc.post_warmup_state.rng_key)
second_100_samples = mcmc.get_samples()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_19176/3851643104.py in <module>
#       1 mcmc = MCMC(HMC(cf.log_like), num_warmup=100, num_samples=200)
# ----> 2 mcmc.run(random.PRNGKey(0), init_params=params)
#       3 first_100_samples = mcmc.get_samples()
#       4 mcmc.post_warmup_state = mcmc.last_state
#       5 mcmc.run(mcmc.post_warmup_state.rng_key)
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/mcmc.py in run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     564         map_args = (rng_key, init_state, init_params)
#     565         if self.num_chains == 1:
# --> 566             states_flat, last_state = partial_map_fn(map_args)
#     567             states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     568         else:
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/mcmc.py in _single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     353         rng_key, init_state, init_params = init
#     354         if init_state is None:
# --> 355             init_state = self.sampler.init(
#     356                 rng_key,
#     357                 self.num_warmup,
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/hmc.py in init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     687                 vmap(random.split)(rng_key), 0, 1
#     688             )
# --> 689         init_params = self._init_state(
#     690             rng_key_init_model, model_args, model_kwargs, init_params
#     691         )
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/hmc.py in _init_state(self, rng_key, model_args, model_kwargs, init_params)
#     633     def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     634         if self._model is not None:
# --> 635             init_params, potential_fn, postprocess_fn, model_trace = initialize_model(
#     636                 rng_key,
#     637                 self._model,
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/util.py in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     573         has_enumerate_support,
#     574         model_trace,
# --> 575     ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     576     # substitute param sites from model_trace to model so
#     577     # we don't need to generate again parameters of `numpyro.module`
#
# ~/.local/lib/python3.8/site-packages/numpyro/infer/util.py in _get_model_transforms(model, model_args, model_kwargs)
#     382 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     383     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 384     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     385     inv_transforms = {}
#     386     # model code may need to be replayed in the presence of deterministic sites
#
# ~/.local/lib/python3.8/site-packages/numpyro/handlers.py in get_trace(self, *args, **kwargs)
#     163         :return: `OrderedDict` containing the execution trace.
#     164         """
# --> 165         self(*args, **kwargs)
#     166         return self.trace
#     167
#
# ~/.local/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/.local/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
# ~/.local/lib/python3.8/site-packages/numpyro/primitives.py in __call__(self, *args, **kwargs)
#      85             return self
#      86         with self:
# ---> 87             return self.fn(*args, **kwargs)
#      88
#      89
#
#     [... skipping hidden 12 frame]
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/fitting.py in log_like(self, params)
#     154     def log_like(self, params=()):
#     155         # calls dc14 and compare to data, (can be gp or gaussian loglikelihood)
# --> 156         d_14_c = self.dc14_FitOffset(params=params)
#     157
#     158         chi2 = jnp.sum(((self.d14c_data[:-1] - d_14_c)/self.d14c_data_error[:-1])**2)
#
#     [... skipping hidden 8 frame]
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/fitting.py in dc14_FitOffset(self, params)
#     139     @partial(jit, static_argnums=(0,))
#     140     def dc14_FitOffset(self, params=()):
# --> 141         burn_in = self.run(self.burn_in_time, self.steady_state_y0, params=params[:-1])
#     142         d_14_c = self.run_D_14_C_values(self.time_data, self.time_oversample, burn_in[-1, :], params=params[:-1])
#     143         return d_14_c - params[-1]
#
#     [... skipping hidden 8 frame]
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/fitting.py in run(self, time_values, y0, params)
#     113     @partial(jit, static_argnums=(0,))
#     114     def run(self, time_values, y0, params=()):
# --> 115         burn_in, _ = self.cbm.run(time_values, production=self.production, args=params, y0=y0)
#     116         return burn_in
#     117
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/ticktack.py in run(self, time_values, production, y0, args, target_C_14, steady_state_production)
#     323
#     324         if USE_JAX:
# --> 325             states = odeint(derivative, y_initial, time_values)
#     326         else:
#     327             states = odeint(derivative, y_initial, time_values)
#
# ~/.local/lib/python3.8/site-packages/jax/experimental/ode.py in odeint(func, y0, t, rtol, atol, mxstep, *args)
#     170       raise TypeError(msg.format(arg))
#     171
# --> 172   converted, consts = custom_derivatives.closure_convert(func, y0, t[0], *args)
#     173   return _odeint_wrapper(converted, rtol, atol, mxstep, y0, t, *args, *consts)
#     174
#
#     [... skipping hidden 15 frame]
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/ticktack.py in derivative(y, t)
#     300         def derivative(y, t):
#     301             ans = jnp.matmul(self._matrix, y)
# --> 302             production_rate_constant = production(t, *args)
#     303             production_rate_constant = self._convert_production_rate(production_rate_constant)
#     304             production_term = self._production_coefficients * production_rate_constant
#
# /usr/local/lib/python3.8/dist-packages/ticktack-0.1.2.1-py3.8.egg/ticktack/fitting.py in f(tval, *args)
#      84                 control_points = jnp.squeeze(jnp.array(list(args)))
#      85                 t = jnp.linspace(self.start-1, self.end, num=len(args), endpoint=True)
# ---> 86                 return jnp.interp(tval, t, control_points)
#      87             self.production = f
#      88
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in interp(x, xp, fp, left, right, period)
#    1563
#    1564   i = clip(searchsorted(xp, x, side='right'), 1, len(xp) - 1)
# -> 1565   df = fp[i] - fp[i - 1]
#    1566   dx = xp[i] - xp[i - 1]
#    1567   delta = x - xp[i - 1]
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _rewriting_take(arr, idx, indices_are_sorted, unique_indices)
#    5007   arr = asarray(arr)
#    5008   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx)
# -> 5009   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    5010                  unique_indices)
#    5011
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices)
#    5016             unique_indices):
#    5017   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 5018   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    5019   y = arr
#    5020
#
# ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in _index_to_gather(x_shape, idx, normalize_indices)
#    5206       if x_shape[x_axis] == 0:
#    5207         # XLA gives error when indexing into an axis of size 0
# -> 5208         raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
#    5209       i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
#    5210       i = lax.convert_element_type(i, index_dtype)
#
# IndexError: index is out of bounds for axis 0 with size 0

# %%
coarse = cf.dc14_FitOffset(params=soln.x)
