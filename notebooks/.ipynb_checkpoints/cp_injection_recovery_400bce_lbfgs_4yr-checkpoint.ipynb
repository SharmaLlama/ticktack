# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

import re
import jax.numpy as jnp
from jax import grad, jit, partial
import ticktack
from ticktack import fitting
from astropy.table import Table
from tqdm import tqdm
from jax.ops import index_update
import scipy

rcParams['figure.figsize'] = (10.0, 5.0)

# %%
cbm = ticktack.load_presaved_model('Guttler14', production_rate_units = 'atoms/cm^2/s')
cf = fitting.CarbonFitter(cbm)
cf.load_data('400_BCE_Data_processed.csv', time_oversample=50)
cf.prepare_function(use_control_points=True, gap_years=5)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
cf.control_points_time
# Out:
# DeviceArray([-427, -426, -418, -413, -408, -403, -398, -390, -382, -375,
#              -367, -361, -355, -349, -343, -337, -331, -325], dtype=int64)

# %%
steady_state = cf.steady_state_production * jnp.ones((len(cf.control_points_time),))
params = steady_state
bounds = tuple([(0, None)] * len(steady_state))

# %%
params.shape
# Out:
# (18,)

# %%
soln = cf.fit_cp(low_bound=0, avg=True, k=2)

# %%
soln.message
# Out:
# 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'

# %%
cf.loss_chi2(params=soln.x)
# Out:
# DeviceArray(9.6903646, dtype=float64)

# %%
plt.plot(cf.control_points_time, soln.x, "ob", fillstyle="none")
plt.ylabel("Production rate ($cm^2s^{-1}$)");
plt.xlabel("Calendar Year");
plt.title(r"Fitted control-points with avg");

# %%
fine = cf.dc14_fine(params=soln.x)
coarse = cf.dc14(params=soln.x)

# %%
plt.plot(cf.time_grid_fine[:-1], fine, "b")
plt.plot(cf.time_data[:-1], coarse, "ob", fillstyle="none", label="fitted")
plt.errorbar(cf.time_data, cf.d14c_data, yerr=cf.d14c_data_error, fmt=".k", label="true")
plt.legend()
plt.ylabel("$\Delta^{14}$C (‰)")
plt.xlabel("Calendar Year");
plt.title("$\Delta$14C data");

# %%
# %%time
cf.grad_log_like(soln.x)
# Out:
# CPU times: user 8.81 s, sys: 109 ms, total: 8.92 s
# Wall time: 8.93 s
# DeviceArray([ 2.0507588 ,  0.06747971, -0.0227177 , -0.3947527 ,
#               0.15765668,  0.20422252,  0.1535911 ,  0.20937329,
#               0.25392861,  0.3395894 , -0.23039116, -0.0825204 ,
#              -0.11286822,  0.21862253,  0.56523423, -0.2671798 ,
#              -0.06975595, -0.42088472], dtype=float64)

# %%
soln.x
# Out:
# array([1.89636017, 1.44580507, 1.8811576 , 2.1507674 , 1.80276473,
#        2.23406508, 1.87885852, 1.92915198, 2.21036406, 2.06033825,
#        2.44716087, 2.20314291, 2.14255201, 2.20198795, 2.06176215,
#        2.12256311, 2.0582041 , 1.63628971])
