# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import warnings
warnings.filterwarnings('ignore')

import re
import jax.numpy as jnp
from jax import grad, jit, partial
import ticktack
from ticktack import fitting
from astropy.table import Table
from tqdm import tqdm
import scipy

rcParams['figure.figsize'] = (8.0, 4.0)

# %%
cbm = ticktack.load_presaved_model('Guttler14', production_rate_units = 'atoms/cm^2/s')
cf = fitting.CarbonFitter(cbm)
cf.load_data('inject-recovery.csv')
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
@jit
def gauss(t):
    start = jnp.nanmin(t)
    end = jnp.nanmax(t)
    mid = start/2+end/2
    prod =  cf.steady_state_production + 0.2 * cf.steady_state_production * jnp.exp(-1/2*((t-775)/3)**2.)
    return prod

# %%
cbm = ticktack.load_presaved_model('Guttler14', production_rate_units = 'atoms/cm^2/s')
cf = fitting.CarbonFitter(cbm)
cf.load_data('inject-recovery.csv')
cf.prepare_function(use_control_points=True, dense_years=1)
soln = cf.fit_cp(low_bound=cf.steady_state_production)

# %%
t = cf.control_points_time
true_cp = gauss(t)
plt.plot(t, gauss(t), ".")
plt.title('Gaussian production rate')
# Out:
# Text(0.5, 1.0, 'Gaussian production rate')

# %%
soln.message
# Out:
# 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'

# %%
cf.loss_chi2(soln.x)
# Out:
# DeviceArray(0.00034369, dtype=float64)

# %%
plt.plot(t, soln.x, ".")
plt.plot(t, true_cp)
plt.title("control points");
plt.legend(["recovered", "true"]);

# %%
plt.plot(cf.time_data[:-1], cf.dc14(soln.x), ".")
plt.plot(cf.time_data, cf.d14c_data)
plt.legend(["recovered", 'true']);
plt.title("d14c");
